# %% [markdown]
# #Examples

# %%
import networkx as nx
import pandas as pd
import json

import smash

# %% [markdown]
# ## Parallel Coordinates

# %%
df = pd.read_csv(smash.cars())
smash.parallel(df, width=800)
# Out:
# <div id="graph_9"></div>
#
# <style type="text/css">
# svg {
#   font: 10px sans-serif;
# }
#
# .background path {
#   fill: none;
#   stroke: #ccc;
#   stroke-opacity: .4;
#   shape-rendering: crispEdges;
# }
#
# .foreground path {
#   fill: none;
#   stroke: #8a89a6;
#   stroke-opacity: .7;
# }
#
# .brush .extent {
#   fill-opacity: .3;
#   stroke: #fff;
#   shape-rendering: crispEdges;
# }
#
# .axis line, .axis path {
#   fill: none;
#   stroke: #000;
#   shape-rendering: crispEdges;
# }
#
# .axis text {
#   text-shadow: 0 1px 0 #fff;
#   cursor: move;
# }
# </style>
#
# <script type="text/javascript">
# graph_9 = function(){
#
# var m = [30, 10, 10, 10],
#     w = 800 - m[1] - m[3],
#     h = 300 - m[0] - m[2];
#
# var x = d3.scale.ordinal().rangePoints([0, w], 1),
#     y = {},
#     dragging = {};
#
# var line = d3.svg.line(),
#     axis = d3.svg.axis().orient("left"),
#     background,
#     foreground;
#
# var svg = d3.select("#graph_9").append("svg:svg")
#     .attr("width", w + m[1] + m[3])
#     .attr("height", h + m[0] + m[2])
#   .append("svg:g")
#     .attr("transform", "translate(" + m[3] + "," + m[0] + ")");
#
# cars = [{"name":"AMC Ambassador Brougham","economy (mpg)":13.0,"cylinders":8,"displacement (cc)":360.0,"power (hp)":175.0,"weight (lb)":3821,"0-60 mph (s)":11.0,"year":73},{"name":"AMC Ambassador DPL","economy (mpg)":15.0,"cylinders":8,"displacement (cc)":390.0,"power (hp)":190.0,"weight (lb)":3850,"0-60 mph (s)":8.5,"year":70},{"name":"AMC Ambassador SST","economy (mpg)":17.0,"cylinders":8,"displacement (cc)":304.0,"power (hp)":150.0,"weight (lb)":3672,"0-60 mph (s)":11.5,"year":72},{"name":"AMC Concord DL 6","economy (mpg)":20.2,"cylinders":6,"displacement (cc)":232.0,"power (hp)":90.0,"weight (lb)":3265,"0-60 mph (s)":18.2,"year":79},{"name":"AMC Concord DL","economy (mpg)":18.1,"cylinders":6,"displacement (cc)":258.0,"power (hp)":120.0,"weight (lb)":3410,"0-60 mph (s)":15.1,"year":78},{"name":"AMC Concord DL","economy (mpg)":23.0,"cylinders":4,"displacement (cc)":151.0,"power (hp)":null,"weight (lb)":3035,"0-60 mph (s)":20.5,"year":82},{"name":"AMC Concord","economy (mpg)":19.4,"cylinders":6,"displacement (cc)":232.0,"power (hp)":90.0,"weight (lb)":3210,"0-60 mph (s)":17.2,"year":78},{"name":"AMC Concord","economy (mpg)":24.3,"cylinders":4,"displacement (cc)":151.0,"power (hp)":90.0,"weight (lb)":3003,"0-60 mph (s)":20.1,"year":80},{"name":"AMC Gremlin","economy (mpg)":18.0,"cylinders":6,"displacement (cc)":232.0,"power (hp)":100.0,"weight (lb)":2789,"0-60 mph (s)":15.0,"year":73},{"name":"AMC Gremlin","economy (mpg)":19.0,"cylinders":6,"displacement (cc)":232.0,"power (hp)":100.0,"weight (lb)":2634,"0-60 mph (s)":13.0,"year":71},{"name":"AMC Gremlin","economy (mpg)":20.0,"cylinders":6,"displacement (cc)":232.0,"power (hp)":100.0,"weight (lb)":2914,"0-60 mph (s)":16.0,"year":75},{"name":"AMC Gremlin","economy (mpg)":21.0,"cylinders":6,"displacement (cc)":199.0,"power (hp)":90.0,"weight (lb)":2648,"0-60 mph (s)":15.0,"year":70},{"name":"AMC Hornet Sportabout (Wagon)","economy (mpg)":18.0,"cylinders":6,"displacement (cc)":258.0,"power (hp)":110.0,"weight (lb)":2962,"0-60 mph (s)":13.5,"year":71},{"name":"AMC Hornet","economy (mpg)":18.0,"cylinders":6,"displacement (cc)":199.0,"power (hp)":97.0,"weight (lb)":2774,"0-60 mph (s)":15.5,"year":70},{"name":"AMC Hornet","economy (mpg)":18.0,"cylinders":6,"displacement (cc)":232.0,"power (hp)":100.0,"weight (lb)":2945,"0-60 mph (s)":16.0,"year":73},{"name":"AMC Hornet","economy (mpg)":19.0,"cylinders":6,"displacement (cc)":232.0,"power (hp)":100.0,"weight (lb)":2901,"0-60 mph (s)":16.0,"year":74},{"name":"AMC Hornet","economy (mpg)":22.5,"cylinders":6,"displacement (cc)":232.0,"power (hp)":90.0,"weight (lb)":3085,"0-60 mph (s)":17.6,"year":76},{"name":"AMC Matador (Wagon)","economy (mpg)":14.0,"cylinders":8,"displacement (cc)":304.0,"power (hp)":150.0,"weight (lb)":4257,"0-60 mph (s)":15.5,"year":74},{"name":"AMC Matador (Wagon)","economy (mpg)":15.0,"cylinders":8,"displacement (cc)":304.0,"power (hp)":150.0,"weight (lb)":3892,"0-60 mph (s)":12.5,"year":72},{"name":"AMC Matador","economy (mpg)":14.0,"cylinders":8,"displacement (cc)":304.0,"power (hp)":150.0,"weight (lb)":3672,"0-60 mph (s)":11.5,"year":73},{"name":"AMC Matador","economy (mpg)":15.0,"cylinders":6,"displacement (cc)":258.0,"power (hp)":110.0,"weight (lb)":3730,"0-60 mph (s)":19.0,"year":75},{"name":"AMC Matador","economy (mpg)":15.5,"cylinders":8,"displacement (cc)":304.0,"power (hp)":120.0,"weight (lb)":3962,"0-60 mph (s)":13.9,"year":76},{"name":"AMC Matador","economy (mpg)":16.0,"cylinders":6,"displacement (cc)":258.0,"power (hp)":110.0,"weight (lb)":3632,"0-60 mph (s)":18.0,"year":74},{"name":"AMC Matador","economy (mpg)":18.0,"cylinders":6,"displacement (cc)":232.0,"power (hp)":100.0,"weight (lb)":3288,"0-60 mph (s)":15.5,"year":71},{"name":"AMC Pacer D\/L","economy (mpg)":17.5,"cylinders":6,"displacement (cc)":258.0,"power (hp)":95.0,"weight (lb)":3193,"0-60 mph (s)":17.8,"year":76},{"name":"AMC Pacer","economy (mpg)":19.0,"cylinders":6,"displacement (cc)":232.0,"power (hp)":90.0,"weight (lb)":3211,"0-60 mph (s) ...

# %% [markdown]
# ##Horizon

# %%
df = pd.read_csv(smash.measured_real_power())
smash.horizon(df.ix[:,0:50], standalone=False, height=500, width=900)
# Out:
# <div id="graph_11"></div>
# <style>
#
#
#
# #horizon-chart {
#   /* position: absolute; */
#   width: 800px;
#   padding: 10px;
#   margin-left: auto;
#   margin-right: auto;
#   z-index: 1;
# }
#
# #horizon-bands {
#   float: right;
# }
#
# </style>
#
#
#
# <script>
#
#
#
# graph_11 = function(){
#
# // d3.json("unemployment.json", function(error, data) {
# // d3.csv("measured_real_power.csv", function(error, data) {
.9,"95":230623.1},"0.8_0.7":{"0":243889.6,"1":254119.0,"2":226060.1,"3":226673.8,"4":173886.9,"5":171898.5,"6":155921.7,"7":138592.0,"8":157580.4,"9":160739.7,"10":151505.7,"11":137359.3,"12":124197.9,"13":118685.1,"14":109382.2,"15":95085.0,"16":102354.9,"17":100571.2,"18":83451.9,"19":89219.3,"20":70556.5,"21":63096.2,"22":33219.9,"23":17641.9,"24":18828.5,"25":24097.1,"26":-14599.9,"27":-11078.5,"28":-3281.3,"29":-7435.6,"30":-12605.5,"31":-4227.4,"32":39977.7,"33":95354.1,"34":89904.9,"35":119541.6,"36":146274.2,"37":181935.0,"38":173341.4,"39":235806.1,"40":296609.2,"41":328787.5,"42":334733.7,"43":323620.2,"44":304843.6,"45":227255.5,"46":225326.5,"47":201794.3,"48":186158.5,"49":281682.0,"50":301304.8,"51":279670.0,"52":246996.7,"53":167940.3,"54":135798.7,"55":111032.0,"56":111194.2,"57":74358.3,"58":78898.6,"59":98633.2,"60":91376.0,"61":50421.2,"62":43513.4,"63":25254.0,"64":1651.0,"65":-18568.5,"66":40112.3,"67":59597.8,"68":122260.6,"69":129090.1,"70":188683.4,"71":207969.6,"72":229892.8,"73":264381.0,"74":293345.2,"75":325272.4,"76":299837.4,"77":337696.3,"78":310106.4,"79":292295.6,"80":279902.1,"81":280649.0,"82": ...

# %% [markdown]
# ##Graphs

# %%
graph = json.loads(open(smash.example_network()).read())

g = nx.DiGraph()
g.add_edges_from([ (x['source'], x['target']) for x in graph])

# %%
smash.graph(g, size=5, font_size=10, height=500)
# Out:
# <div id="graph_13"></div>
# <!-- <script src="http://d3js.org/d3.v3.min.js"></script> -->
# <style>
# #graph{
#     float: left;
# }
#
# .overlay {
#   fill: none;
#   pointer-events: all;
# }
#
# text{
#     font-family: sans-serif;
#     /* font-size: 3px; */
#     font-color: grey;
#     shape-rendering: crispEdges;
# }
#
# #table{
#     float: right;
# }
# #graph{
#     float: left;
# }
#
# #data{
#     font-family: sans-serif;
#     font-size: 9px;
#     font-color: grey;
# }
#
# table{
#     width: 300px;
#     margin-left: 0px;
#     font-size: 12px;
#     table-layout: fixed;
#
# }
#
# th{
#     text-align: left;
# }
#
# td, th {
#     width: 140px;
#     word-wrap:break-word;
#     padding: 1px 4px;
# }
# </style>
#
# <script type="text/javascript">
# graph_13 = function(){
#
# var margin = {top: 50, right: 20, bottom: 50, left:20},
#     width = 700 - margin.left - margin.right,
#     height = 500 - margin.top - margin.bottom;
#
# var svg_13 = d3.select("#graph_13").append("svg")
#     .attr("width", width + margin.left + margin.right)
#     .attr("height", height + margin.top + margin.bottom)
#     .append("g")
#     .call(d3.behavior.zoom().scaleExtent([0.75, 8]).on("zoom", zoom_13))
#     .append("g");
#
# svg_13.append("rect")
#     .attr("class", "overlay")
#     .attr("width", width + margin.left + margin.right)
#     .attr("height", height + margin.top + margin.bottom);
#
#
#     draw = function(edges, nodes, svg){
#
#      var x_scale = d3.scale.linear()
#                     .domain([d3.min(nodes, function(d){ return d['x'];}),
#                              d3.max(nodes, function(d){ return d['x'];})])
#                     .range([0, width]);
#
#     var y_scale = d3.scale.linear()
#                     .domain([d3.min(nodes, function(d){ return d['y'];}),
#                              d3.max(nodes, function(d){ return d['y'];})])
#                     .range([height, 0]);
#
#
#     svg.selectAll("line")
#        .data(edges)
#        .enter()
#        .append("line")
#        .attr("x1", function(d) { return x_scale(d['x1']); })
#        .attr("y1", function(d) { return y_scale(d['y1']); })
#        .attr("x2", function(d) { return x_scale(d['x2']); })
#        .attr("y2", function(d) { return y_scale(d['y2']); })
#        .attr("stroke-width", function(d) { return d['stroke_width']; })
#        .attr("stroke","#d3d3d3");
#
#     svg.selectAll("circle")
#        .data(nodes)
#        .enter()
#        .append("circle")
#        .attr("cx", function(d) { return x_scale(d['x']); })
#        .attr("cy", function(d) { return y_scale(d['y']); })
#        .attr("r",  function(d) { return d['size']; })
#        .attr("fill",  function(d) { return d3.rgb(d['color'][0]*255,
#                                                   d['color'][1]*255,
#                                                   d['color'][2]*255); })
#        .attr("stroke-width",  0.15)
#        .attr("stroke",  function(d) { return "#d3d3d3"; });
#
#     svg.selectAll("text")
#        .data(nodes)
#        .enter()
#        .append("text")
#        .attr("x", function(d) { return x_scale(d['x']); })
#        .attr("y", function(d) { return y_scale(d['y']); })
#        .attr("dy", ".55em")
#         .attr("fill","#d3d3d3")
#        .attr("font-size", function(d){ console.log(d['font_size']); return d['font_size'] + "px";})
#        .text(function(d){ return d['name']; });
#
#     }
#
#     var edges_13 = [{"y1": -192.51, "x2": -430.89, "x1": -401.16, "y2": -268.1, "stroke_width": 1}, {"y1": -155.17, "x2": 274.6, "x1": 299.08, "y2": -217.34, "stroke_width": 1}, {"y1": -277.36, "x2": -58.752, "x1": -9.9131, "y2": -267.93, "stroke_width": 1}, {"y1": -277.36, "x2": -31.175, "x1": -9.9131, "y2": -348.3, "stroke_width": 1}, {"y1": -192.28, "x2": 79.711, "x1": 105.8, "y2": -240.7, "stroke_width": 1}, {"y1": -240.7, "x2": 11.429, "x1": 79.711, "y2": -175.81, "stroke_width": 1}, {"y1": -133.74, "x2": -54.003, "x1": -25.191, "y2": -226.87, "stroke_width": 1}, {"y1": -133.18, "x2": 105.8, "x1": 40.844, "y2": -192.28, "stroke_width": 1}, {"y1": -133.18, "x2": 63.332, "x1": 40.844, "y2": -218.26, "stroke_width": 1}, {"y1": -239.49, "x2": 63.332, "x1": 6.8318, "y2": -218.26, "stroke_width": 1}, {"y1": -239.49, "x2": -9.9131, "x1": 6.8318, "y2": -277.36, "stroke_width": 1}, {"y1": -239.49, "x2": -54.003, "x1": 6.8318, "y2": -226.87, "stroke_width": 1}, {"y1": -175.81, "x2": -9.9131, "x1": 11.429, "y2": -277.36, "stroke_width": 1}, {"y1": -175.81, "x2": 6.8318, "x1": 11.429, "y2": -239.49, "stroke_width": 1}, {"y1": -175.81, "x2": 39.327, "x1": 11.429, "y2": -269.6, "stroke_width": 1}, {"y1": -269.6, "x2": -9.9131, "x1": 39.327, "y2": -277.36, "stroke_width": 1}, {"y1": -269.6, "x2": 6.8318, "x1": 39.327, "y2": -239.49, "stroke_width": 1}, {"y1": -196.57, "x2": -401.16, "x1": -489.91, "y2