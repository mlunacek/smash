# %%
import smash

import pandas as pd

df = pd.read_csv(smash.measured_real_power())
smash.horizon(df.ix[:,0:50], standalone=False, height=300, width=500)
# Out:
# <div id="graph_3"></div>
# <style>
#
#
#
# #horizon-chart {
#   /* position: absolute; */
#   width: 800px;
#   padding: 10px;
#   margin-left: auto;
#   margin-right: auto;
#   z-index: 1;
# }
#
# #horizon-bands {
#   float: right;
# }
#
# </style>
#
#
#
# <script>
#
#
#
# graph_3 = function(){
#
# // d3.json("unemployment.json", function(error, data) {
# // d3.csv("measured_real_power.csv", function(error, data) {
# ...
